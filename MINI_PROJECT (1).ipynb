# %%
# !pip install bing-image-downloader

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
# !ls
# Out:
# drive  images  sample_data

# %%
cd images
# Out:
# /content/images

# %%
from bing_image_downloader import downloader
downloader.download("car",limit=6,output_dir='images')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 6 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.ytimg.com/vi/TObBn68uRSA/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/uFf1j4c70s8/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.topgear.com/sites/default/files/styles/16x9_1280w/public/images/gallery-migration/2015-06/5289C724-F9DB-4108-83FE-421AB36AC3E1.jpg?itok=zexfafqi
# [!] Issue getting: https://www.topgear.com/sites/default/files/styles/16x9_1280w/public/images/gallery-migration/2015-06/5289C724-F9DB-4108-83FE-421AB36AC3E1.jpg?itok=zexfafqi
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #3 from https://i.ytimg.com/vi/moFQhZ0_-TU/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.trbimg.com/img-57c049f1/turbine/ct-history-worlds-fastest-cars-under-200000-20160825
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("bike",limit=6,output_dir='images')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 6 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.ytimg.com/vi/mUYs6jWVVys/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/rFCFNPCHxnY/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.ytimg.com/vi/xpCuEM0GoyE/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/Bi5cCCTqoM0/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.ytimg.com/vi/PmyA14LkmSk/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ytimg.com/vi/pQEUECn05Ho/maxresdefault.jpg
# [%] File Downloaded !

# %%
path ='/content/drive/My Drive/PYTHONNN/images/images/car/Image_1.jpg'
import cv2
import matplotlib.pyplot as plt
i=cv2.imread(path)
plt.imshow(i)
i= cv2.cvtColor(i,cv2.COLOR_BGR2RGB)

# %%
#PreProcessing of Data

import os
import cv2
path ='/content/drive/My Drive/PYTHONNN/images/images/car'
for filename in os.listdir(path):
  i=cv2.imread(os.path.join(path,filename))
  print(filename)
  print(i)
import numpy as ap
# Out:
# Image_1.jpg
# [[[  0   0 153]
#   [  0   0 153]
#   [  0   0 152]
#   ...
#   [  2  66 100]
#   [  1  71  94]
#   [  0  72  90]]
#
#  [[  0   0 150]
#   [  0   0 150]
#   [  0   1 151]
#   ...
#   [  4  67 101]
#   [  5  72  97]
#   [  7  76  96]]
#
#  [[  1   2 146]
#   [  1   2 146]
#   [  2   2 150]
#   ...
#   [ 11  67 102]
#   [  6  66  95]
#   [  5  69  93]]
#
#  ...
#
#  [[147 144 139]
#   [145 142 137]
#   [143 140 135]
#   ...
#   [ 76  71  68]
#   [ 76  71  68]
#   [ 76  71  68]]
#
#  [[144 141 136]
#   [146 143 138]
#   [144 141 136]
#   ...
#   [ 76  71  68]
#   [ 76  71  68]
#   [ 76  71  68]]
#
#  [[142 139 134]
#   [147 144 139]
#   [146 143 138]
#   ...
#   [ 76  71  68]
#   [ 76  71  68]
#   [ 76  71  68]]]
# Image_2.jpg
# [[[189 184 183]
#   [189 184 183]
#   [189 184 183]
#   ...
#   [102  91  87]
#   [102  91  87]
#   [102  91  87]]
#
#  [[189 184 183]
#   [189 184 183]
#   [189 184 183]
#   ...
#   [102  91  87]
#   [102  91  87]
#   [102  91  87]]
#
# ...

# %%
#scaling of data

import os
import numpy as np
from skimage.io import imread
from skimage.transform import resize
target=[]
flat_data=[]
images=[]
path='/content/drive/My Drive/PYTHONNN/images/images/'
for dirpath,dirnames,filenames in os.walk(path):
  for filename in filenames:
   category= dirpath.split('/')[-1]
   target.append(category)
   img = imread(f'{path}{category}/{filename}')
  
   img_resized= resize(img,(50,50,3))
   flat_data.append(img_resized.flatten())
   images.append(img_resized)

flat_data=np.array(flat_data)
target=np.array(target)
images=np.array(images)


print(flat_data.shape)
print(target.shape)
print(images.shape)
# Out:
# (12, 7500)
# (12,)
# (12, 50, 50, 3)

# %%
import pandas as pd
df=pd.DataFrame(flat_data)
df['Target']=target
df.shape
df.head()
# Out:
#           0         1         2         3  ...      7497      7498      7499  Target
# 0  0.581569  0.003922  0.007843  0.697647  ...  0.278431  0.290196  0.309804     car
# 1  0.721922  0.726667  0.739255  0.716588  ...  0.160784  0.160784  0.160784     car
# 2  0.390588  0.390588  0.413765  0.466667  ...  0.121569  0.078431  0.078431     car
# 3  0.539216  0.209412  0.078431  0.399608  ...  0.239216  0.176471  0.179216     car
# 4  0.231373  0.168627  0.180392  0.235294  ...  0.330863  0.244588  0.252431     car
#
# [5 rows x 7501 columns]

# %%
df.nunique()
# Out:
# 0         11
# 1         11
# 2         11
# 3         11
# 4         10
#           ..
# 7496      11
# 7497      12
# 7498      12
# 7499      12
# Target     2
# Length: 7501, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
model =KNeighborsClassifier(n_neighbors=7)
x=flat_data
y=target

model.fit(x,y)
import numpy as np
z=np.arange(1,10)


from sklearn.model_selection import GridSearchCV

param={'n_neighbors':z}
model = KNeighborsClassifier()
model_grid= GridSearchCV(model,param)

model_grid.fit(x,y)
model_grid.best_params_
# Out:
# {'n_neighbors': 7}

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=0)
model= KNeighborsClassifier(n_neighbors=9)
model.fit(x_train,y_train)

y_pred = model.predict(x_test)
y_pred
# Out:
# array(['car', 'car', 'car'], dtype='<U4')

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.3333333333333333

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[0, 0],
#        [2, 1]])

# %%
#Predicting Output

from skimage.io import imread
import matplotlib.pyplot as plt


i=imread('https://www.autocar.co.uk/sites/autocar.co.uk/files/images/car-reviews/first-drives/legacy/large-2479-s-classsaloon.jpg')


plt.imshow(i)

# %%
from skimage.io import imread
import os
import cv2
import numpy as np
from skimage.transform import resize

img =imread("https://images.hindustantimes.com/auto/img/2020/04/03/960x540/amby_1585896460277_1585896460484.jpg")

img.flatten()
# Out:
# array([237, 245, 255, ..., 213, 206, 200], dtype=uint8)

# %%
#Predicting output
import cv2
import os
import numpy as np
from skimage.io import imread
from skimage.transform import resize
target=[]
flat_data=[]
images=[]

img = imread('https://images.hindustantimes.com/auto/img/2020/04/03/960x540/amby_1585896460277_1585896460484.jpg')
img.reshape(1,-1)
img_resized= resize(img,(50,50,3))
flat_data.append(img_resized.flatten())
images.append(img_resized)

flat_data=np.array([flat_data])
target=np.array(target)
images=np.array(images)


print(flat_data.shape)
print(images.shape)
plt.imshow(img_resized)
i =img_resized.transpose(2,0,1).reshape(3,-1)
a = np.array(i)
from PIL import Image
im = Image.fromarray(a)
plt.imshow(im)
# Out:
# (1, 1, 7500)
# (1, 50, 50, 3)

# %%
model.predict(im)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-ed339e2a2ea7> in <module>()
# ----> 1 model.predict(im)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     171         X = check_array(X, accept_sparse='csr')
#     172
# --> 173         neigh_dist, neigh_ind = self.kneighbors(X)
#     174         classes_ = self.classes_
#     175         _y = self._y
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     641                 X, self._fit_X, reduce_func=reduce_func,
#     642                 metric=self.effective_metric_, n_jobs=n_jobs,
# --> 643                 **kwds))
#     644
#     645         elif self._fit_method in ['ball_tree', 'kd_tree']:
#
# ...

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement pil (from versions: none)
# ERROR: No matching distribution found for pil
